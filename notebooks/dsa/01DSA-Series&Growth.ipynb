# %% [markdown]
# $ \sum_{i=n_1}^{n_2} c = (n_2 - n_1) c $
#
# ---
#
# geometric series
#
# $$ S = a + ar + ar^2 + ar^3 + \dots + ar^{n-1} $$
#
# $$ S_n = a \cdot \frac{1 - r^n}{1 - r}, \quad \text{for } r \neq 1 $$
#
# $ |r| < 1 $: $$ S = \frac{a}{1 - r} $$
#
# ---
#
# $ \lim_{n=0}^\infty \frac{2n+1}{n+1} = 2 \to \theta(c) \quad \text{or} \quad \theta(1)$
#
# ---
# absorbtion rule:
#
# $ 2^n + n^5 - \log(n) =  \theta(2^n)$
#
# ---
# log family:
#
# * the base doesn't matter: $ \log_3(n) = \frac{\log_2(n)}{\log_{2}3} = \theta(\log_2(n)) $
#
# ---
#
# for $ 1 + 2 + 3 + \dots + \frac{n}{2} + (\frac{n}{2}+1) + \dots + n $
#
# sum of a series of numbers is from $ \Theta(n^2) $ also in the case of partial sum:
#
# $ \Theta(n^2) $ : $\begin{cases} \sum_{i=1}^n = \Theta(n^2) \\ \sum_{i=1}^{\frac{n}{2}} = \Theta(n^2) \\ \sum_{\frac{n}{2}}^{n} = \Theta(n^2) \end{cases} $
#
# ---
#
# solve for  $ T(n) = \sum_{i=1}^n (i + \frac{1}{i} )$
#
# $ \sum_{i=1}^n (i + \frac{1}{i} ) = \Theta(n^2 + \ln(n)) = \Theta(n^2) $
