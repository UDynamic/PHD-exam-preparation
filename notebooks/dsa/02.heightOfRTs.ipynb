# %% [markdown]
# $ T(n) = A \cdot T(n-c) + f(n) \to h = \frac{n}{c} $
#
# ---
#
# $ T(n) = A \cdot T(\sqrt(n)) + f(n) $
#
# $ n = 2^k \to k = \log(n) $
#
# $ T(2^k) = A \cdot T(2^{\frac{k}{2}}) + f(2^k) $
#
# $ T(2^k) = F(k) \to F(k) = A \cdot F(\frac{k}{2}) + f(2^k)$
#
# $ h_F = \log_2(k) \to^{k = \log(n)} h_T = \log(log(n))$
#
# ---
#
# Note: absorbtion rule for both nominator and denominator in fractional Ts
#
# $ T(\frac{k}{2} + c) = T(\frac{k}{2}) $
#
# $ T(\frac{n}{n^\frac{2}{3} + 1}) = T(n^\frac{1}{3}) = T(\sqrt[3]{n}) $
#
# $ T(\frac{n^2 + 3}{\sqrt{n} + 5}) = T(\frac{n^2}{\sqrt{n}}) = T(n^{\frac{2}{3}}) $
#
# $ T(\frac{2n + 1}{3}) = T(\frac{2n}{3}) $
#
# * floor and ceil are effectless:
#
# $  T(\lceil \frac{k}{2} \rceil) = T(\lfloor \frac{k}{2} \rfloor) = T(\frac{k}{2})$
#
#
# ---
# for $ 0 < c < 1$
#
# $ T(n) = A \cdot T(n^c) + f(n) $
#
# $ h_T = \log_\frac{1}{c}(log(n)) $
#
# ---
#
# Height of the RT for :
#
# $ T(n,k) = T(\frac{n}{2}, k) + T(n, \frac{k}{4}) + f(n,k) \quad, T(1,k)=1, \quad T(n,1)=1$
#
# max hieght belongs to the branch that does divisions intervally:
#
# $ h = \log_2(n) + \log_4(k) $
