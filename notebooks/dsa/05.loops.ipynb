# %% [markdown]
# Count for the steps in :
#
# $ \text{for}(i=1, i \leq n, i=i+c) \to \frac{n}{c} \text{Times} $
#
# $ \text{for}(i=n, i \geq 1, i=i-c) \to \frac{n}{c} \text{Times}$
#
# $ \text{for}(i=m, i \leq n, i=i+c) \to \frac{n-m}{c} \text{Times} $
#
# $ \text{for}(i=1, i \leq n, i= i *c ) \to \log_c(n) \text{Times}$
#
# $ \text{for}(i=n, i \geq 1, i=\frac{i}{c}) \to \log_c(n) \text{Times}$
#
# $ \text{for}(i=m, i \leq n, i= i *c ) \to \log_c(\frac{n}{m}) \text{Times}$
#
# ---
#
# we could write each loop as a $ \Sigma $:
#
# * if independant (outer simgma has no effect on the bounds or the inside parameter of the inner sigma):
# we could multiply their complexity estimatates to the final answer.
#
# ######e.g.
#
# $\text{Do } (i=1, i \leq n, i++) $
#
# $\quad \text{Do } (j=1, j \leq n, j=j+i) $
#
# $\quad \quad \text{Do } (k=1, k \leq n, k=k*2) $
#
# $\quad \quad \quad x++;$
#
# $\quad \quad \quad y++;$
#
#
# seperate the problem into 2 :
#
# * k loop is independant so we would multiply it to the answer of the other parts
#
# $ k=k*2 \to \sum_{k=1}^n (2) = 2 log_2(n) = \Theta(log(n)) $
#
# * J loop is dependant to the i :$\quad  j=j+i \to \sum_{j=1}^n = \frac{n}{i} $
# * I loop : $\quad i++ \to \sum_{i=1}^n \frac{n}{i} = n log(n)$
#
# $ \rightarrow \Theta(n \log(n) \cdot \log(n))$
#
# ######e.g.
#
# $\text{Do } (i=1, i \leq n, i++) $
#
# {
#
# $\quad \text{Do } (j=1, j \leq n, j++) $
#
# $\quad \quad x++;$
#
# $\quad n--;$
#
# }
#
#
# Each outer iteration reduces n by only 1, so inner loop runs $n, n-1, n-2, ...$ times → Sum = $\Theta(n^2)$
#
# * $n$ and $i$ will meet at the $ \frac{n}{2} $ .
# * according to condition it will run until $ i > \frac{n}{2} $ but the sum is still from order of $ n^2 $
#
# ######e.g.
#
# $\text{Do } (i=1, i \leq n, i++) $
#
# {
#
# $\quad \text{Do } (j=1, j \leq n, j++) $
#
# $\quad \quad x++;$
#
# $\quad \quad n--;$
#
# }
#
#
# for Each outer iteration n gets half, so inner loop runs $\frac{n}{2}, \frac{n}{4}, \frac{n}{8}, ...$ times → Sum = $\Theta(n)$
#
# * $n$ and $j$ will meet at the $ \frac{n}{2} $ .
# * according to condition it will run until $ j > \frac{n}{2} $
